# %%
import pandas as pd
collection = pd.read_csv('forward_snowballing_1.csv')

def add_criteria_columns(prefix):
    for x in range(1, 6):
        collection[prefix + str(x)] = False

# Add selection criteria as columns
add_criteria_columns('i') # Inclusion
add_criteria_columns('e') # Exclusion

collection
# Out:
#          Key        Item Type  Publication Year  \
# 0   XENBJP9B  conferencePaper              2008
# 1   5JTXRBSV  conferencePaper              2011
# 2   7Q37UI9S   journalArticle              2014
# 3   CWUMUWPQ           thesis              2007
# 4   BW8CFLUP   journalArticle              2016
# 5   3QM8DTAQ  conferencePaper              2016
# 6   S5K5ZCUY  conferencePaper              2016
# 7   NRT2IS7G  conferencePaper              2013
# 8   Z8IP73RF   journalArticle              2012
# 9   CXTI5UZ7   journalArticle              2019
# 10  FQ26V5S9             book              2013
# 11  Z3SPAG2M   journalArticle              2019
# 12  PRA9R8TS  conferencePaper              2012
# 13  KGAZNXPG  conferencePaper              2012
# 14  KCQCK3ZH  conferencePaper              2019
# 15  C63SNJZX   journalArticle              2017
# 16  CJSW5DK7  conferencePaper              2006
# 17  NB8IDQC7  conferencePaper              2005
# 18  9J429DXW   journalArticle              2006
# 19  62WT3M4A  conferencePaper              2005
# 20  5ICRS9ZS           thesis              2007
# 21  Q5RDCWBS  conferencePaper              2012
# 22  MJJ5FVSE   journalArticle              2015
# 23  YAYTQ8TV  conferencePaper              2012
# 24  TG8EJE9Y   journalArticle              2010
# 25  SEALIJ6E   journalArticle              2009
# 26  JW8P32EP   journalArticle              2011
# 27  EIK7X9UD  conferencePaper              2007
# 28  ZWP93KSV   journalArticle              2010
# 29  5Q7VF7DW      bookSection              2013
# 30  W33KR9VE           thesis              2007
# 31  MHQTTDWD   journalArticle              2009
# 32  N9QS7EZ4  conferencePaper              2016
# 33  FPHIG2PR  conferencePaper              2011
# 34  3IBZAPY9           thesis              2015
# 35  I88VKD9J  conferencePaper              2016
# 36  9KGQIQTW  conferencePaper              2016
# 37  9WGJLA88   journalArticle              2016
# 38  THMYW972   journalArticle              2020
# 39  9ZK6MGHD  conferencePaper              2017
# 40  STWMQ4ZU   journalArticle              2019
# 41  LLQLKJYF           thesis              2013
# 42  IXXLDVBQ   journalArticle              2016
# 43  BP8XAHUH  conferencePaper              2018
#
#                                                Author  \
# 0   Borgstrom, Per Henrik; Singh, Amarjeet; Jordan...
# 1    Rassõlkin, Anton; Hõimoja, Hardi; Teemets, Raivo
# 2        Salan, Serge; Drumwright, Evan; Lin, King-Ip
# 3                                        Mei, Yongguo
# 4   Henkel, Christian; Bubeck, Alexander; Xu, Weil...
# 5   Bartlett, Oliver; Gurau, Corina; Marchegiani, ...
# 6                                    Rappaport, Micha
# 7                 Ogunniyi, Samuel; Tsoeu, Mohohlo S.
# 8                         Kottas, Apostolos Dimitrios
# 9   Wu, Lingying; Sugiyama, Ayumi; Sugawara, Toshi...
# 10                                Salan, Serge Antoun
# 11  Benkrid, Abdenour; Benallegue, Abdelaziz; Acho...
# 12        Patel, Sonali; Shukla, Anupam; Tiwari, Ritu
# 13        Patel, Sonali; Tiwari, Ritu; Shukla, Anupam
# 14             Firdaus, N.; Samat, H. A.; Mohamad, N.
# 15   Carabin, Giovanni; Wehrle, Erich; Vidoni, Renato
# 16  Mei, Yongguo; Lu, Yung-Hsiang; Lee, CS George;...
# 17  Mei, Yongguo; Lu, Yung-Hsiang; Hu, Y. Charlie;...
# 18  Mei, Yongguo; Lu, Yung-Hsiang; Hu, Yu Charlie;...
# 19                    Kim, Chong Hui; Kim, Byung Kook
# 20                                       Mei, Yongguo
# 21        Patel, Sonali; Shukla, Anupam; Tiwari, Ritu
# 22               Lysenko, V.; Bolbot, І.; Chernov, І.
# 23        Patel, Sonali; Tiwari, Ritu; Shukla, Anupam
# 24  Stirling, Timothy; Wischmann, Steffen; Florean...
# 25          Ooi, Chia Ching; Schindelhauer, Christian
# 26             Ghaffarkhah, Alireza; Mostofi, Yasamin
# 27                           Zhang, Wei; Hu, Jianghai
# 28  Stirling, Timothy; Wischmann, Steffen; Florean...
# 29                 Stirling, Timothy; Floreano, Dario
# 30                                       Mei, Yongguo
# 31                    Shahab, Mohammad; Masoud, Ahmed
# 32                                   Rappaport, Micha
# 33  Moraes, Elisabete Nakoneczny; Becker, Leandro ...
# 34                                 Broderick, John A.
# 35    Sattayasoonthorn, Preedipat; Suthakorn, Jackrit
# 36  Benkrid, Abdenour; Benallegue, Abdelaziz; Acho...
# 37                    Jaleel, Hassan; Shamma, Jeff S.
# 38  Jaramillo-Morales, Mauricio F.; Dogru, Sedat; ...
# 39               Yang, Huizhen; Li, Ruizhen; Yun, Niu
# 40                                 Chaim, Michael Ben
# 41                                       Yu, Shengwei
# 42        Stanhouse, Kyle; Kitts, Chris; Mas, Ignacio
# 43  Angelina, Seilla; Afifah, Shofuro; Susamti, Pa...
#
#                                                 Title  \
# 0   Energy based path planning for a novel cabled ...
# 1   Energy saving possibilities in the industrial ...
# 2   Minimum-energy robotic exploration: A formulat...
# 3                      Energy-efficient mobile robots
# 4   Energy efficient dynamic window approach for l...
# 5   Enabling intelligent energy management for rob...
# 6   Energy-aware mobile robot exploration with ada...
# 7   Q-learning based energy efficient path plannin...
# 8   Energy-efficient designs and principles for mi...
# 9   Energy-efficient strategies for multi-agent co...
# 10  Minimum-energy exploration and coverage for ro...
# 11  Multi-robot Coordination for Energy-Efficient ...
# 12  Efficient strategy for co-ordinated multirobot...
# 13      An energy efficient platform for mobile robot
# 14        Maintenance for Energy efficiency: A Review
# 15  A review on energy-saving optimization methods...
# 16          Energy-efficient mobile robot exploration
# 17  A case study of mobile robot's energy consumpt...
# 18  Deployment of mobile robots with energy and ti...
# 19  Energy-saving 3-step velocity control algorith...
# 20                     Energy-efficient mobile robots
# 21  Efficient strategy for co-ordinated multirobot...
# 22  The optimization of power consumption of mobil...
# 23      An energy efficient platform for mobile robot
# 24  Energy-efficient indoor search by swarms of si...
# 25   Minimal energy path planning for wireless robots
# 26  Communication-aware motion planning in mobile ...
# 27  Low power management for autonomous mobile rob...
# 28  Energy-efficient indoor search by swarms of si...
# 29  Energy-time efficiency in aerial swarm deployment
# 30                     Energy-efficient mobile robots
# 31   Energy-Efficient Motion Control of Mobile Robots
# 32  Energy-aware mobile robot exploration with ada...
# 33  Framework for estimating energy consumption in...
# 34  Energy and Mobility Management of a Ground Rob...
# 35      Battery management for rescue robot operation
# 36  Robot's energy consumption based multi-robot e...
# 37  Energy Aware Architecture for Coordinated Mobi...
# 38  Energy estimation for differential drive mobil...
# 39  Tradeoff between battery life and control qual...
# 40  Energy Limitations and Energetic Efficiency of...
# 41      Energy optimization in mobile sensor networks
# 42  Time-Energy Optimal Cluster Space Motion Plann...
# 43  Efficient energy consumption for indoor mobile...
#
#                                     Publication Title  ISBN  ISSN  DOI  Url  \
# 0   2008 IEEE/RSJ International Conference on Inte...   NaN   NaN  NaN  NaN
# 1   2011 7th International Conference-Workshop Com...   NaN   NaN  NaN  NaN
# 2   IEEE Transactions on Systems, Man, and Cyberne...   NaN   NaN  NaN  NaN
# 3                                                 NaN   NaN   NaN  NaN  NaN
# 4                                   IFAC-PapersOnLine   NaN   NaN  NaN  NaN
# 5   2016 IEEE/RSJ International Conference on Inte...   NaN   NaN  NaN  NaN
# 6   Proceedings of ISR 2016: 47st International Sy...   NaN   NaN  NaN  NaN
# 7   24th Symposium of the Pattern Recognition Asso...   NaN   NaN  NaN  NaN
# 8                                                 NaN   NaN   NaN  NaN  NaN
# 9                           Procedia Computer Science   NaN   NaN  NaN  NaN
# 10                                                NaN   NaN   NaN  NaN  NaN
# 11  Journal of Control, Automation and Electrical ...   NaN   NaN  NaN  NaN
# 12  Proceedings of the Second International Confer...   NaN   NaN  NaN  NaN
# 13                         AIP Conference Proceedings   NaN   NaN  NaN  NaN
# 14  IOP Conference Series: Materials Science and E...   NaN   NaN  NaN  NaN
# 15                                           Robotics   NaN   NaN  NaN  NaN
# 16  Proceedings 2006 IEEE International Conference...   NaN   NaN  NaN  NaN
# 17  ICAR'05. Proceedings., 12th International Conf...   NaN   NaN  NaN  NaN
# 18                      IEEE Transactions on robotics   NaN   NaN  NaN  NaN
# 19  Proceedings of the 2005 IEEE international con...   NaN   NaN  NaN  NaN
# 20                                                NaN   NaN   NaN  NaN  NaN
# 21  Proceedings of the Second International Confer...   NaN   NaN  NaN  NaN
# 22                                Системні технології   NaN   NaN  NaN  NaN
# 23                         AIP Conference Proceedings   NaN   NaN  NaN  NaN
# 24                                 Swarm Intelligence   NaN   NaN  NaN  NaN
# 25                   Mobile Networks and Applications   NaN   NaN  NaN  NaN
# 26             IEEE Transactions on Automatic Control   NaN   NaN  NaN  NaN
# 30  ...  False  False  False  False  False  False  False  False  False  False
# 31  ...  False  False  False  False  False  False  False  False  False  False
# 32  ...  False  False  False  False  False  False  False  False  False  False
# 33  ...  False  False  False  False  False  False  False  False  False  False
# 34  ...  False  False  False  False  False  False  False  False  False  False
# 35  ...  False  False  False  False  False  False  False  False  False  False
# 36  ...  False  False  False  False  False  False  False  False  False  False
# 37  ...  False  False  False  False  False  False  False  False  False  False
# 38  ...  False  False  False  False  False  False  False  False  False  False
# 39  ...  False  False  False  False  False  False  False  False  False  False
# 40  ...  False  False  False  False  False  False  False  False  False  False
# 41  ...  False  False  False  False  False  False  False  False  False  False
# 42  ...  False  False  False  False  False  False  False  False  False  False
# 43  ...  False  False  False  False  False  False  False  False  False  False
#
# [44 rows x 97 columns]

# %%
# Filter records based on types that are to be considered (peer reviewed by nature).
def filter_types(col):
    df = pd.DataFrame(columns=col.columns)
    for index, row in col.iterrows():
        item_type = row['Item Type']
        if "journalArticle" in item_type or \
            "conferencePaper" in item_type or \
            "bookSection" in item_type or \
            "book" in item_type:
            row['i4'] = True
            df.loc[len(df)] = row
    
    return df

# Filter duplicates but keep highest priority variant.
def filter_duplicates(col):
    seen = list()
    df = pd.DataFrame(columns=col.columns)
    for index, row in col.iterrows():
        title = row['Title']
        itemType = row['Item Type']
        
        # Convert itemType from str to priority integer (lower = better)
        if itemType == "journalArticle":
            itemType = 0
        elif itemType == "conferencePaper":
            itemType = 1
        elif itemType == "book":
            itemType = 2
        elif itemType == "bookSection":
            itemType = 3
        
        # Create 3-tuple of important, necessary items.
        item = (index, title, itemType)
        
        if not item[1] in [t[1] for t in seen]:       # If title not yet seen, add it to DF and to seen
            df_index = len(df)
            df.loc[df_index] = row
            item = (df_index, item[1], item[2])       # Update index of item to new index in new DF
            seen.append(item)
        else:
            stored_item = [t for t in seen if t[1] == item[1]][0] # Retrieve stored_item which has title seen (dup)
            if stored_item[2] > item[2]:              # If current item has higher priority than stored item, update
                df.drop(stored_item[0])               # Drop original from DF
                df_index = len(df)                    # Index at which item will be placed
                df.loc[df_index] = row                # Place row at index
                item = (df_index, item[1], item[2])   # Update item index to new index in new DF
                seen[seen.index(stored_item)] = item  # Update seen by overwriting stored_item to current item
                
    return df

# Purely for testing, not used at all and should not be used on the collection.
# Only to get an indication of the amount of papers that are more explicit in the title.
def filter_titles(col):
    df = pd.DataFrame(columns=col.columns)
    for index, row in col.iterrows():
        title = row['Title']
        if "efficiency" in title or \
            "consumption" in title or \
            "optimisation" in title or \
            "optimization" in title or \
            "modeling" in title or \
            "analysis" in title:
            df.loc[len(df)] = row

    return df

# %%
# Filter the collection based on 'peer review by nature' types as discussed in email contact.
col_types = filter_types(collection)

# %%
# Filter duplicates and keep highest priority ones, export to CSV (final record set).
col_dups = filter_duplicates(col_types)
col_dups.to_csv("forward_snowballing_1_filtered.csv")
