# %%
import pandas as pd
collection = pd.read_csv('google_scholar_683_relevant_studies.csv')

## The different files that can be used to process them into the filtered data:

# google_scholar_683_relevant_studies.csv
# raw_data/backward_snowballing_iteration_1.csv
# raw_data/backward_snowballing_iteration_2.csv
# raw_data/forward_snowballing_iteration_1.csv

def add_criteria_columns(prefix, max_range):
    for x in range(1, max_range + 1):
        collection[prefix + str(x)] = False

# Add selection criteria as columns
add_criteria_columns('i', 6) # Inclusion
add_criteria_columns('e', 5) # Exclusion

collection
# Out:
#          Key        Item Type  Publication Year  \
# 0   SN9QLFVM  conferencePaper              2016
# 1   VCVUEFIU   journalArticle              2011
# 2   6NDLPMD6  conferencePaper              2009
# 3   N3WSCPHD   journalArticle              2017
# 4   TLMKA8PC   journalArticle              2013
# 5   6SB6EC8L   journalArticle              2015
# 6   3Z9TY6HA   journalArticle              2015
# 7   26ECU8KV   journalArticle              2019
# 8   RUVJIB22   journalArticle              2016
# 9   47WMULEZ  conferencePaper              2004
# 10  R39AJHIR   journalArticle              2003
# 11  RFJYANZH  conferencePaper              1995
# 12  UVIHKKAP  conferencePaper              2003
# 13  7N8QSIFC  conferencePaper              2004
# 14  EIG8F4AF  conferencePaper              2004
# 15  3E37MG3H   journalArticle              2002
# 16  J68AFIYQ   journalArticle              2001
# 17  TRQEE557   journalArticle              2017
# 18  DHKQT37C   journalArticle              2014
# 19  82X96YCJ   journalArticle              2005
# 20  Q59HC2G5   journalArticle              2013
# 21  T27IG94J   journalArticle              2003
# 22  974ZYICN   journalArticle              2007
# 23  H4E7N98K   journalArticle              2013
# 24  DE9MGVQ4  conferencePaper              2005
#
#                                                Author  \
# 0   Benkrid, Abdenour; Benallegue, Abdelaziz; Acho...
# 1         Puig, Domenec; García, Miguel Angel; Wu, L.
# 2   Karnouskos, Stamatis; Colombo, Armando Walter;...
# 3    Carabin, Giovanni; Wehrle, Erich; Vidoni, Renato
# 4   Pellicciari, Marcello; Berselli, Giovanni; Lea...
# 5   Pellegrinelli, Stefania; Borgia, Stefano; Pedr...
# 6   Brossog, Matthias; Bornschlegl, Martin; Franke...
# 7   Gadaleta, Michele; Pellicciari, Marcello; Bers...
# 8   Bukata, Libor; Š\uucha, Přemysl; Hanzálek, Zde...
# 9   Mei, Yongguo; Lu, Yung-Hsiang; Hu, Y. Charlie;...
# 10                  Rakhmatov, Daler; Vrudhula, Sarma
# 11                 Barili, A.; Ceresa, M.; Parisi, C.
# 12             Batalin, Maxim A.; Sukhatme, Gaurav S.
# 13  Chang, H. Jacky; Lee, CS George; Lu, Yung-Hsia...
# 14       Jia, Menglei; Zhou, GuangMing; Chen, ZongHai
# 15  Raghunathan, Vijay; Schurgers, Curt; Park, Sun...
# 16                                 Laughlin, Simon B.
# 17  Hou, Gang; Zhou, Kuanjiu; Qiu, Tie; Cao, Xun; ...
# 18  Magurawalage, Chathura M. Sarathchandra; Yang,...
# 19                          Sun, Zheng; Reif, John H.
# 20                             Liu, Shuang; Sun, Dong
# 21                 Duleba, Ignacy; Sasiadek, Jurek Z.
# 22                    Kim, Chong Hui; Kim, Byung Kook
# 23                      Kim, Hongjun; Kim, Byung Kook
# 24  Mei, Yongguo; Lu, Yung-Hsiang; Hu, Y. Charlie;...
#
#                                                 Title  \
# 0   Robot's energy consumption based multi-robot e...
# 1   A new global optimization strategy for coordin...
# 2         Towards the energy efficient future factory
# 3   A review on energy-saving optimization methods...
# 4   A method for reducing the energy consumption o...
# 5   Minimization of the energy consumption in moti...
# 6   Reducing the energy consumption of industrial ...
# 7   Optimization of the energy consumption of indu...
# 8                Energy optimization of robotic cells
# 9   Energy-efficient motion planning for mobile ro...
# 10  Energy management for battery-powered embedded...
# 11  Energy-saving motion control for an autonomous...
# 12         Efficient exploration without localization
# 13  Energy-time-efficient adaptive dispatching alg...
# 14  An efficient strategy integrating grid and top...
# 15         Energy-aware wireless microsensor networks
# 16  Energy as a constraint on the coding and proce...
# 17  A novel green software evaluation model for cl...
# 18  Energy-efficient and network-aware offloading ...
# 19     On finding energy-minimizing paths on terrains
# 20  Minimizing energy consumption of wheeled mobil...
# 21  Nonholonomic motion planning based on Newton a...
# 22  Minimum-energy translational trajectory genera...
# 23  Online minimum-energy trajectory planning and ...
# 24  A case study of mobile robot's energy consumpt...
#
#                                     Publication Title  ISBN  ISSN  DOI  Url  \
# 0   2016 IEEE International Conference on Robotics...   NaN   NaN  NaN  NaN
# 1                     Robotics and Autonomous Systems   NaN   NaN  NaN  NaN
# 2   2009 7th IEEE International Conference on Indu...   NaN   NaN  NaN  NaN
# 3                                            Robotics   NaN   NaN  NaN  NaN
# 4                                        Mechatronics   NaN   NaN  NaN  NaN
# 5                                       Procedia Cirp   NaN   NaN  NaN  NaN
# 6   The International Journal of Advanced Manufact...   NaN   NaN  NaN  NaN
# 7      Robotics and Computer-Integrated Manufacturing   NaN   NaN  NaN  NaN
# 8         IEEE Transactions on Industrial Informatics   NaN   NaN  NaN  NaN
# 9   IEEE International Conference on Robotics and ...   NaN   NaN  NaN  NaN
# 10  ACM Transactions on Embedded Computing Systems...   NaN   NaN  NaN  NaN
# 11  1995 Proceedings of the IEEE International Sym...   NaN   NaN  NaN  NaN
# 12  2003 IEEE International Conference on Robotics...   NaN   NaN  NaN  NaN
# 13  IEEE International Conference on Robotics and ...   NaN   NaN  NaN  NaN
# 14  IEEE Conference on Robotics, Automation and Me...   NaN   NaN  NaN  NaN
# 15                    IEEE Signal processing magazine   NaN   NaN  NaN  NaN
# 16                    Current opinion in neurobiology   NaN   NaN  NaN  NaN
# 17                 Computers & Electrical Engineering   NaN   NaN  NaN  NaN
# 18                                  Computer Networks   NaN   NaN  NaN  NaN
# 19                      IEEE Transactions on Robotics   NaN   NaN  NaN  NaN
# 20             IEEE/ASME Transactions on Mechatronics   NaN   NaN  NaN  NaN
# 21    IEEE transactions on control systems technology   NaN   NaN  NaN  NaN
# 22         Journal of Intelligent and Robotic Systems   NaN   NaN  NaN  NaN
# 23        IEEE Transactions on industrial electronics   NaN   NaN  NaN  NaN
# 24  ICAR'05. Proceedings., 12th International Conf...   NaN   NaN  NaN  NaN
#
#     ...     i2     i3     i4     i5     i6     e1     e2     e3     e4     e5
# 0   ...  False  False  False  False  False  False  False  False  False  False
# 1   ...  False  False  False  False  False  False  False  False  False  False
# 2   ...  False  False  False  False  False  False  False  False  False  False
# 3   ...  False  False  False  False  False  False  False  False  False  False
# 4   ...  False  False  False  False  False  False  False  False  False  False
# 5   ...  False  False  False  False  False  False  False  False  False  False
# 6   ...  False  False  False  False  False  False  False  False  False  False
# 7   ...  False  False  False  False  False  False  False  False  False  False
# 8   ...  False  False  False  False  False  False  False  False  False  False
# 9   ...  False  False  False  False  False  False  False  False  False  False
# 10  ...  False  False  False  False  False  False  False  False  False  False
# 11  ...  False  False  False  False  False  False  False  False  False  False
# 12  ...  False  False  False  False  False  False  False  False  False  False
# 13  ...  False  False  False  False  False  False  False  False  False  False
# 14  ...  False  False  False  False  False  False  False  False  False  False
# 15  ...  False  False  False  False  False  False  False  False  False  False
# 16  ...  False  False  False  False  False  False  False  False  False  False
# 17  ...  False  False  False  False  False  False  False  False  False  False
# 18  ...  False  False  False  False  False  False  False  False  False  False
# 19  ...  False  False  False  False  False  False  False  False  False  False
# 20  ...  False  False  False  False  False  False  False  False  False  False
# 21  ...  False  False  False  False  False  False  False  False  False  False
# 22  ...  False  False  False  False  False  False  False  False  False  False
# 23  ...  False  False  False  False  False  False  False  False  False  False
# 24  ...  False  False  False  False  False  False  False  False  False  False
#
# [25 rows x 98 columns]

# %%
# Filter records based on types that are to be considered (peer reviewed by nature).
def filter_types(col):
    df = pd.DataFrame(columns=col.columns)
    for index, row in col.iterrows():
        item_type = row['Item Type']
        if "journalArticle" in item_type or \
            "conferencePaper" in item_type or \
            "bookSection" in item_type or \
            "book" in item_type:
            row['i4'] = True
            df.loc[len(df)] = row
    
    return df

# Filter duplicates but keep highest priority variant.
def filter_duplicates(col):
    seen = list()
    df = pd.DataFrame(columns=col.columns)
    for index, row in col.iterrows():
        title = row['Title']
        itemType = row['Item Type']
        
        # Convert itemType from str to priority integer (lower = better)
        if itemType == "journalArticle":
            itemType = 0
        elif itemType == "conferencePaper":
            itemType = 1
        elif itemType == "book":
            itemType = 2
        elif itemType == "bookSection":
            itemType = 3
        
        # Create 3-tuple of important, necessary items.
        item = (index, title, itemType)
        
        if not item[1] in [t[1] for t in seen]:       # If title not yet seen, add it to DF and to seen
            df_index = len(df)
            df.loc[df_index] = row
            item = (df_index, item[1], item[2])       # Update index of item to new index in new DF
            seen.append(item)
        else:
            stored_item = [t for t in seen if t[1] == item[1]][0] # Retrieve stored_item which has title seen (dup)
            if stored_item[2] > item[2]:              # If current item has higher priority than stored item, update
                df.drop(stored_item[0])               # Drop original from DF
                df_index = len(df)                    # Index at which item will be placed
                df.loc[df_index] = row                # Place row at index
                item = (df_index, item[1], item[2])   # Update item index to new index in new DF
                seen[seen.index(stored_item)] = item  # Update seen by overwriting stored_item to current item
                
    return df

# Purely for testing, not used at all and should not be used on the collection.
# Only to get an indication of the amount of papers that are more explicit in the title.
def filter_titles(col):
    df = pd.DataFrame(columns=col.columns)
    for index, row in col.iterrows():
        title = row['Title']
        if "efficiency" in title or \
            "consumption" in title or \
            "optimisation" in title or \
            "optimization" in title or \
            "modeling" in title or \
            "analysis" in title:
            df.loc[len(df)] = row

    return df

# %%
# Filter the collection based on 'peer review by nature' types as discussed in email contact.
col_types = filter_types(collection)
col_types
# Out:
#           Key        Item Type  Publication Year  \
# 0    6BH5WM7V   journalArticle            2017.0
# 1    CAV3PKJB   journalArticle            2007.0
# 2    LCA5ZRZQ  conferencePaper            2010.0
# 3    8YQZGJKS   journalArticle            2005.0
# 4    GK66MU6T  conferencePaper            2006.0
# ..        ...              ...               ...
# 610  XF5HJDYH   journalArticle            2018.0
# 611  8CEZTE8L   journalArticle            2019.0
# 612  GXWNQ2F3   journalArticle            2001.0
# 613  YUR8N5QG   journalArticle            2011.0
# 614  DEN4F9BF   journalArticle            2011.0
#
#                                                 Author  \
# 0    Du, Zhihui; He, Ligang; Chen, Yinong; Xiao, Yu...
# 1    Han, Jun; Asada, Akira; Ura, Tamaki; Yamauchi,...
# 2    Wang, Binhai; Chen, Xiguang; Wang, Qian; Liu, ...
# 3                        CAI, Gai-pin; HUANG, Zhi-qing
# 4    Mei, Yongguo; Lu, Yung-Hsiang; Lee, CS George;...
# ..                                                 ...
# 610  Abadi, Vida Shams Esfand; Rostami, Mostafa; Ra...
# 611                Almécija Murciano, Francisco Javier
# 612                                   Krstulović, Ante
# 613                                                王文俊
# 614  Peña Cortés, César Augusto; Martínez Oviedo, E...
#
#                                                  Title  \
# 0    Robot Cloud: Bridging the power of robotics an...
# 1    Noncontact power supply for seafloor geodetic ...
# 2            Power line inspection with a flying robot
# 3    The Realization of the Industrial Revolving Tu...
# 4            Energy-efficient mobile robot exploration
# ..                                                 ...
# 610  Walking Path Prevision of Biped Robot along wi...
# 611     Power management strategies for a mobile robot
# 612         Robot Energy Efficiency Through Redundancy
# 613  高效率電源管理之智慧型僕役機器人-總計畫: 高效率電源管理之智慧型僕役機器人; Intell...
# 614  Dimentional optimization of a Delta parallel r...
#
#                                      Publication Title  ISBN  ISSN  DOI  Url  \
# 0                   Future Generation Computer Systems   NaN   NaN  NaN  NaN
# 1             Journal of marine science and technology   NaN   NaN  NaN  NaN
# 2    2010 1st International Conference on Applied R...   NaN   NaN  NaN  NaN
# 3                            Machine Tool & Hydraulics   NaN   NaN  NaN  NaN
# 4    Proceedings 2006 IEEE International Conference...   NaN   NaN  NaN  NaN
# ..                                                 ...   ...   ...  ...  ...
# 610                     Modares Mechanical Engineering   NaN   NaN  NaN  NaN
# 611                                                NaN   NaN   NaN  NaN  NaN
# 612                                        Strojarstvo   NaN   NaN  NaN  NaN
# 613                             財團法人國家實驗研究院科技政策研究與資訊中心   NaN   NaN  NaN  NaN
# 614                  Ciencia e Ingeniería Neogranadina   NaN   NaN  NaN  NaN
#
#      ...     i1     i2     i3    i4     i5     e1     e2     e3     e4     e5
# 0    ...  False  False  False  True  False  False  False  False  False  False
# 1    ...  False  False  False  True  False  False  False  False  False  False
# 2    ...  False  False  False  True  False  False  False  False  False  False
# 3    ...  False  False  False  True  False  False  False  False  False  False
# 4    ...  False  False  False  True  False  False  False  False  False  False
# ..   ...    ...    ...    ...   ...    ...    ...    ...    ...    ...    ...
# 610  ...  False  False  False  True  False  False  False  False  False  False
# 611  ...  False  False  False  True  False  False  False  False  False  False
# 612  ...  False  False  False  True  False  False  False  False  False  False
# 613  ...  False  False  False  True  False  False  False  False  False  False
# 614  ...  False  False  False  True  False  False  False  False  False  False
#
# [615 rows x 97 columns]

# %%
# Filter duplicates and keep highest priority ones, export to CSV (final record set).
col_dups = filter_duplicates(col_types)
col_dups.to_csv("processed_data/forward_snowballing_1_filtered.csv")

# processed_data/backward_snowballing_iteration_1_filtered.csv
# processed_data/backward_snowballing_iteration_2_filtered.csv
# processed_data/forward_snowballing_iteration_1_filtered.csv
# Out:
#           Key        Item Type  Publication Year  \
# 0    6BH5WM7V   journalArticle            2017.0
# 1    CAV3PKJB   journalArticle            2007.0
# 2    LCA5ZRZQ  conferencePaper            2010.0
# 3    8YQZGJKS   journalArticle            2005.0
# 4    GK66MU6T  conferencePaper            2006.0
# ..        ...              ...               ...
# 605  XF5HJDYH   journalArticle            2018.0
# 606  8CEZTE8L   journalArticle            2019.0
# 607  GXWNQ2F3   journalArticle            2001.0
# 608  YUR8N5QG   journalArticle            2011.0
# 609  DEN4F9BF   journalArticle            2011.0
#
#                                                 Author  \
# 0    Du, Zhihui; He, Ligang; Chen, Yinong; Xiao, Yu...
# 1    Han, Jun; Asada, Akira; Ura, Tamaki; Yamauchi,...
# 2    Wang, Binhai; Chen, Xiguang; Wang, Qian; Liu, ...
# 3                        CAI, Gai-pin; HUANG, Zhi-qing
# 4    Mei, Yongguo; Lu, Yung-Hsiang; Lee, CS George;...
# ..                                                 ...
# 605  Abadi, Vida Shams Esfand; Rostami, Mostafa; Ra...
# 606                Almécija Murciano, Francisco Javier
# 607                                   Krstulović, Ante
# 608                                                王文俊
# 609  Peña Cortés, César Augusto; Martínez Oviedo, E...
#
#                                                  Title  \
# 0    Robot Cloud: Bridging the power of robotics an...
# 1    Noncontact power supply for seafloor geodetic ...
# 2            Power line inspection with a flying robot
# 3    The Realization of the Industrial Revolving Tu...
# 4            Energy-efficient mobile robot exploration
# ..                                                 ...
# 605  Walking Path Prevision of Biped Robot along wi...
# 606     Power management strategies for a mobile robot
# 607         Robot Energy Efficiency Through Redundancy
# 608  高效率電源管理之智慧型僕役機器人-總計畫: 高效率電源管理之智慧型僕役機器人; Intell...
# 609  Dimentional optimization of a Delta parallel r...
#
#                                      Publication Title  ISBN  ISSN  DOI  Url  \
# 0                   Future Generation Computer Systems   NaN   NaN  NaN  NaN
# 1             Journal of marine science and technology   NaN   NaN  NaN  NaN
# 2    2010 1st International Conference on Applied R...   NaN   NaN  NaN  NaN
# 3                            Machine Tool & Hydraulics   NaN   NaN  NaN  NaN
# 4    Proceedings 2006 IEEE International Conference...   NaN   NaN  NaN  NaN
# ..                                                 ...   ...   ...  ...  ...
# 605                     Modares Mechanical Engineering   NaN   NaN  NaN  NaN
# 606                                                NaN   NaN   NaN  NaN  NaN
# 607                                        Strojarstvo   NaN   NaN  NaN  NaN
# 608                             財團法人國家實驗研究院科技政策研究與資訊中心   NaN   NaN  NaN  NaN
# 609                  Ciencia e Ingeniería Neogranadina   NaN   NaN  NaN  NaN
#
#      ...     i1     i2     i3    i4     i5     e1     e2     e3     e4     e5
# 0    ...  False  False  False  True  False  False  False  False  False  False
# 1    ...  False  False  False  True  False  False  False  False  False  False
# 2    ...  False  False  False  True  False  False  False  False  False  False
# 3    ...  False  False  False  True  False  False  False  False  False  False
# 4    ...  False  False  False  True  False  False  False  False  False  False
# ..   ...    ...    ...    ...   ...    ...    ...    ...    ...    ...    ...
# 605  ...  False  False  False  True  False  False  False  False  False  False
# 606  ...  False  False  False  True  False  False  False  False  False  False
# 607  ...  False  False  False  True  False  False  False  False  False  False
# 608  ...  False  False  False  True  False  False  False  False  False  False
# 609  ...  False  False  False  True  False  False  False  False  False  False
#
# [610 rows x 97 columns]
