# %%
import pandas as pd
collection = pd.read_csv('google_scholar_683.csv')
collection
# Out:
#           Key        Item Type  Publication Year  \
# 0    6BH5WM7V   journalArticle            2017.0
# 1    CAV3PKJB   journalArticle            2007.0
# 2    LCA5ZRZQ  conferencePaper            2010.0
# 3    8YQZGJKS   journalArticle            2005.0
# 4    GK66MU6T  conferencePaper            2006.0
# ..        ...              ...               ...
# 678  XF5HJDYH   journalArticle            2018.0
# 679  8CEZTE8L   journalArticle            2019.0
# 680  GXWNQ2F3   journalArticle            2001.0
# 681  YUR8N5QG   journalArticle            2011.0
# 682  DEN4F9BF   journalArticle            2011.0
#
#                                                 Author  \
# 0    Du, Zhihui; He, Ligang; Chen, Yinong; Xiao, Yu...
# 1    Han, Jun; Asada, Akira; Ura, Tamaki; Yamauchi,...
# 2    Wang, Binhai; Chen, Xiguang; Wang, Qian; Liu, ...
# 3                        CAI, Gai-pin; HUANG, Zhi-qing
# 4    Mei, Yongguo; Lu, Yung-Hsiang; Lee, CS George;...
# ..                                                 ...
# 678  Abadi, Vida Shams Esfand; Rostami, Mostafa; Ra...
# 679                Almécija Murciano, Francisco Javier
# 680                                   Krstulović, Ante
# 681                                                王文俊
# 682  Peña Cortés, César Augusto; Martínez Oviedo, E...
#
#                                                  Title  \
# 0    Robot Cloud: Bridging the power of robotics an...
# 1    Noncontact power supply for seafloor geodetic ...
# 2            Power line inspection with a flying robot
# 3    The Realization of the Industrial Revolving Tu...
# 4            Energy-efficient mobile robot exploration
# ..                                                 ...
# 678  Walking Path Prevision of Biped Robot along wi...
# 679     Power management strategies for a mobile robot
# 680         Robot Energy Efficiency Through Redundancy
# 681  高效率電源管理之智慧型僕役機器人-總計畫: 高效率電源管理之智慧型僕役機器人; Intell...
# 682  Dimentional optimization of a Delta parallel r...
#
#                                      Publication Title  ISBN  ISSN  DOI  Url  \
# 0                   Future Generation Computer Systems   NaN   NaN  NaN  NaN
# 1             Journal of marine science and technology   NaN   NaN  NaN  NaN
# 2    2010 1st International Conference on Applied R...   NaN   NaN  NaN  NaN
# 3                            Machine Tool & Hydraulics   NaN   NaN  NaN  NaN
# 4    Proceedings 2006 IEEE International Conference...   NaN   NaN  NaN  NaN
# ..                                                 ...   ...   ...  ...  ...
# 678                     Modares Mechanical Engineering   NaN   NaN  NaN  NaN
# 679                                                NaN   NaN   NaN  NaN  NaN
# 680                                        Strojarstvo   NaN   NaN  NaN  NaN
# 681                             財團法人國家實驗研究院科技政策研究與資訊中心   NaN   NaN  NaN  NaN
# 682                  Ciencia e Ingeniería Neogranadina   NaN   NaN  NaN  NaN
#
#      ...  Programming Language Version System Code  Code Number Section  \
# 0    ...                   NaN     NaN    NaN  NaN          NaN     NaN
# 1    ...                   NaN     NaN    NaN  NaN          NaN     NaN
# 2    ...                   NaN     NaN    NaN  NaN          NaN     NaN
# 3    ...                   NaN     NaN    NaN  NaN          NaN     NaN
# 4    ...                   NaN     NaN    NaN  NaN          NaN     NaN
# ..   ...                   ...     ...    ...  ...          ...     ...
# 678  ...                   NaN     NaN    NaN  NaN          NaN     NaN
# 679  ...                   NaN     NaN    NaN  NaN          NaN     NaN
# 680  ...                   NaN     NaN    NaN  NaN          NaN     NaN
# 681  ...                   NaN     NaN    NaN  NaN          NaN     NaN
# 682  ...                   NaN     NaN    NaN  NaN          NaN     NaN
#
#      Session Committee  History  Legislative Body
# 0        NaN       NaN      NaN               NaN
# 1        NaN       NaN      NaN               NaN
# 2        NaN       NaN      NaN               NaN
# 3        NaN       NaN      NaN               NaN
# 4        NaN       NaN      NaN               NaN
# ..       ...       ...      ...               ...
# 678      NaN       NaN      NaN               NaN
# 679      NaN       NaN      NaN               NaN
# 680      NaN       NaN      NaN               NaN
# 681      NaN       NaN      NaN               NaN
# 682      NaN       NaN      NaN               NaN
#
# [683 rows x 87 columns]

# %%
def filter_types(col):
    df = pd.DataFrame(columns=col.columns)
    for index, row in col.iterrows():
        item_type = row['Item Type']
        df['Item Type'].unique()
        if "journalArticle" in item_type or \
            "conferencePaper" in item_type or \
            "bookSection" in item_type or \
            "book" in item_type:
            df.loc[len(df)] = row

def filter_titles(col):
    df = pd.DataFrame(columns=col.columns)
    for index, row in col.iterrows():
        title = row['Title']
        if "efficiency" in title or \
            "consumption" in title or \
            "optimisation" in title or \
            "optimization" in title or \
            "modeling" in title or \
            "analysis" in title:
            df.loc[len(df)] = row

    return df

# %%
filter_types(filter_titles(collection))
# Out:
# Key                                                          6BH5WM7V
# Item Type                                              journalArticle
# Publication Year                                                 2017
# Author              Du, Zhihui; He, Ligang; Chen, Yinong; Xiao, Yu...
# Title               Robot Cloud: Bridging the power of robotics an...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 0, Length: 87, dtype: object
# Key                                                          CAV3PKJB
# Item Type                                              journalArticle
# Publication Year                                                 2007
# Author              Han, Jun; Asada, Akira; Ura, Tamaki; Yamauchi,...
# Title               Noncontact power supply for seafloor geodetic ...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 1, Length: 87, dtype: object
# Key                                                          LCA5ZRZQ
# Item Type                                             conferencePaper
# Publication Year                                                 2010
# Author              Wang, Binhai; Chen, Xiguang; Wang, Qian; Liu, ...
# Title                       Power line inspection with a flying robot
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 2, Length: 87, dtype: object
# Key                                                          8YQZGJKS
# Item Type                                              journalArticle
# Publication Year                                                 2005
# Author                                  CAI, Gai-pin; HUANG, Zhi-qing
# Title               The Realization of the Industrial Revolving Tu...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 3, Length: 87, dtype: object
# Key                                                          GK66MU6T
# Item Type                                             conferencePaper
# Publication Year                                                 2006
# Author              Mei, Yongguo; Lu, Yung-Hsiang; Lee, CS George;...
# Title                       Energy-efficient mobile robot exploration
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 4, Length: 87, dtype: object
# Key                                                        ZGTSYZW3
# Item Type                                           conferencePaper
# Publication Year                                               2008
# Author              Katrasnik, Jaka; Pernus, Franjo; Likar, Bostjan
# Title                           New robot for power line inspection
#                                          ...
# Section                                                         NaN
# Session                                                         NaN
# Committee                                                       NaN
# History                                                         NaN
# Legislative Body                                                NaN
# Name: 5, Length: 87, dtype: object
# Key                                                          NEDPNXGK
# Item Type                                             conferencePaper
# Publication Year                                                 2016
# Author              Dong, Pengfei; Wang, Xuezhu; Xing, Hongjun; Li...
# Title               Design and control of a tracked robot for sear...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 6, Length: 87, dtype: object
# Key                                                          7Q3RHEZQ
# Item Type                                              journalArticle
# Publication Year                                                 2010
# Author                                            Li, Zheng; Ruan, Yi
# Title               Autonomous inspection robot for power transmis...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 7, Length: 87, dtype: object
# Key                                                          SL9LQ8LA
# Item Type                                              journalArticle
# Publication Year                                                 2008
# Author                              Ngo, Trung Dung; Schiøler, Henrik
# Title               Truly autonomous robots: hardware design for a...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 8, Length: 87, dtype: object
# Key                                                          MMG79GRQ
# Item Type                                              journalArticle
# Publication Year                                                 2017
# Author              Riazi, Sarmad; Wigström, Oskar; Bengtsson, Kri...
# Title               Energy and peak power optimization of time-bou...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 9, Length: 87, dtype: object
# Key                                                          CUN4VXEB
# Item Type                                             conferencePaper
# Publication Year                                                 2007
# Author                           Montambault, Serge; Pouliot, Nicolas
# Title               Design and validation of a mobile robot for po...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 10, Length: 87, dtype: object
# Key                                                          SX9QJ4WG
# Item Type                                              journalArticle
# Publication Year                                                 2014
# Author              Paes, Koen; Dewulf, Wim; Vander Elst, Karel; K...
# Title               Energy efficient trajectories for an industria...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 11, Length: 87, dtype: object
# Key                                                          HKCETG66
# Item Type                                             conferencePaper
# Publication Year                                                 2011
# Author              Chan, Hoi; Connell, Jonathan; Isci, Canturk; K...
# Title               A robot as mobile sensor and agent in data cen...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 12, Length: 87, dtype: object
# Key                                                          V3347KDQ
# Item Type                                             conferencePaper
# Publication Year                                                 2008
# Author              Pinto, José Kleber da Cunha; Masuda, M.; Magri...
# Title               Mobile robot for hot spot monitoring in electr...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 13, Length: 87, dtype: object
# Key                                                          9N93DHNX
# Item Type                                             conferencePaper
# Publication Year                                                 2007
# Author              Gurdan, Daniel; Stumpf, Jan; Achtelik, Michael...
# Title               Energy-efficient autonomous four-rotor flying ...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 14, Length: 87, dtype: object
# Key                                                          TP9HHVBN
# Item Type                                              journalArticle
# Publication Year                                                 2005
# Author              Lucas, Nestor; Codrea, Cosmin; Hirth, Thomas; ...
# Title               RoBM2: measurement of battery capacity in mobi...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 15, Length: 87, dtype: object
# Key                                                          B7HZQKVY
# Item Type                                             conferencePaper
# Publication Year                                                 2005
# Author              Zhou, F. Y.; Wang, J. D.; Li, Y. B.; Wang, J.;...
# Title               Control of an inspection robot for 110KV power...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 16, Length: 87, dtype: object
# Key                                                          R3EXKXCY
# Item Type                                              journalArticle
# Publication Year                                                 2012
# Author              Vergnano, Alberto; Thorstensson, Carl; Lennart...
# Title               Modeling and optimization of energy consumptio...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 17, Length: 87, dtype: object
# Key                                                       IRY65HTX
# Item Type                                          conferencePaper
# Publication Year                                              2009
# Author              Guo, Rui; Li, Bingqiang; Sun, Yutian; Han, Lei
# Title                 A patrol robot for electric power substation
#                                          ...
# Section                                                        NaN
# Session                                                        NaN
# Committee                                                      NaN
# History                                                        NaN
# Legislative Body                                               NaN
# Name: 18, Length: 87, dtype: object
# Key                                                          CZVWRKW7
# Item Type                                             conferencePaper
# Publication Year                                                 2008
# Author                           Montambault, Serge; Pouliot, Nicolas
# Title               Design and validation of a mobile robot for po...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 19, Length: 87, dtype: object
# Key                                                          6CYUEI9R
# Item Type                                             conferencePaper
# Publication Year                                                 1976
# Author                Orin, David E.; McGhee, Robert B.; Jaswa, V. C.
# Title               Interactive compute-control of a six-legged ro...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 21, Length: 87, dtype: object
# Key                                                          KSXP9MWE
# Item Type                                              journalArticle
# Publication Year                                                 2014
# Author              Mohammed, Abdullah; Schmidt, Bernard; Wang, Li...
# Title               Minimizing energy consumption for robot arm mo...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 22, Length: 87, dtype: object
# Key                                                          AYFHS29U
# Item Type                                              journalArticle
# Publication Year                                                 2016
# Author              Ramos, Ernesto Zamora; Ramos, Maria; Moutafis,...
# Title               Robot-Server Architecture for Optimizing Solar...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 23, Length: 87, dtype: object
# Key                                                          EAKZR2CI
# Item Type                                             conferencePaper
# Publication Year                                                 2001
# Author                              Gemeinder, Marcus; Gerke, Michael
# Title               GA-based search for paths with minimum energy ...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 24, Length: 87, dtype: object
# Key                                                          M8YT9G2R
# Item Type                                             conferencePaper
# Publication Year                                                 2010
# Author              Bailón, W. Pérez; Cardiel, E. Barrera; Campos,...
# Title               Mechanical energy optimization in trajectory p...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 25, Length: 87, dtype: object
# Key                                                          XWHTDXA2
# Item Type                                              journalArticle
# Publication Year                                                 2018
# Author              Lima, Eduardo José; Bomfim, Marcelo Henrique S...
# Title                            POLIBOT–POwer Lines Inspection RoBOT
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 26, Length: 87, dtype: object
# Key                                                        RNENNFB4
# Item Type                                            journalArticle
# Publication Year                                               1995
# Author              Bach, Fr-W.; Rachkov, M.; Seevers, J.; Hahn, M.
# Title                       High tractive power wall-climbing robot
#                                          ...
# Section                                                         NaN
# Session                                                         NaN
# Committee                                                       NaN
# History                                                         NaN
# Legislative Body                                                NaN
# Name: 27, Length: 87, dtype: object
# Key                                                          FQ7PA9XH
# Item Type                                                 bookSection
# Publication Year                                                 2008
# Author              LIMA, JOSÉ L.; GONÇALVES, JOSÉ C.; COSTA, PAUL...
# Title               Realistic humanoid robot simulation with an op...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 28, Length: 87, dtype: object
# Key                                                          XTY8DLR8
# Item Type                                              journalArticle
# Publication Year                                                 2012
# Author                              Kiguchi, Kazuo; Hayashi, Yoshiaki
# Title               An EMG-based control for an upper-limb power-a...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 29, Length: 87, dtype: object
# Key                                                          NMJC5SMH
# Item Type                                              journalArticle
# Publication Year                                                 2005
# Author              YANG, Qi-zhi; YIN, Xiao-gin; MA, Lu-zhong; DU,...
# Title               Establishing stiffness of prismatic pair in fu...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 30, Length: 87, dtype: object
# Key                                                          X3DE7CQM
# Item Type                                             conferencePaper
# Publication Year                                                 2003
# Author                             Luo, R. C.; Su, K. L.; Deng, C. W.
# Title               Multisensor based power diagnosis system for a...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 31, Length: 87, dtype: object
# Key                                                          YEBNK85H
# Item Type                                             conferencePaper
# Publication Year                                                 2005
# Author                                                 Siregar, H. P.
# Title               Simulation of power consumption for walking robot
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 32, Length: 87, dtype: object
# Key                                                          LCHVX88W
# Item Type                                              journalArticle
# Publication Year                                                 2008
# Author              Minakata, Hideaki; Seki, Hirokazu; Tadakuma, S...
# Title               A study of energy-saving shoes for robot consi...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 33, Length: 87, dtype: object
# Key                                                          9ADAMC3V
# Item Type                                              journalArticle
# Publication Year                                                 2014
# Author                Mostashfi, A.; Fakhari, A.; Badri, Mohammad Ali
# Title               A novel design of inspection robot for high-vo...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 34, Length: 87, dtype: object
# Key                                                          98KPBTVT
# Item Type                                              journalArticle
# Publication Year                                                 2008
# Author                                 He, Yingxin; Tatsuno, Kyouichi
# Title               An Example of Open Robot Controller Architectu...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 35, Length: 87, dtype: object
# Key                                                          SJWTYJG3
# Item Type                                             conferencePaper
# Publication Year                                                 2016
# Author              Fenucci, Alba; Indri, Marina; Romanelli, Fabrizio
# Title               An off-line robot motion planning approach for...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 36, Length: 87, dtype: object
# Key                                                          A58BTBJS
# Item Type                                             conferencePaper
# Publication Year                                                 2010
# Author              Vergnano, Alberto; Thorstensson, Carl; Lennart...
# Title               Embedding detailed robot energy optimization i...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 37, Length: 87, dtype: object
# Key                                                          FP5V6SKH
# Item Type                                             conferencePaper
# Publication Year                                                 2006
# Author              Sun, Cuilian; Wang, Hongguang; Zhao, Mingyang;...
# Title               3D simulation and optimization design of a mob...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 38, Length: 87, dtype: object
# Key                                                          JSQACQBT
# Item Type                                              journalArticle
# Publication Year                                                 2013
# Author              Schmidt, Bernard; Mohammed, Abdullah; Wang, Lihui
# Title               Minimising energy consumption for robot arm mo...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 40, Length: 87, dtype: object
# Key                                                          WQS695JK
# Item Type                                                 bookSection
# Publication Year                                                 2012
# Author              Bhounsule, Pranav A.; Cortell, Jason; Ruina, Andy
# Title               Design and control of Ranger: an energy-effici...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 41, Length: 87, dtype: object
# Key                                                          JCH233KK
# Item Type                                              journalArticle
# Publication Year                                                 2017
# Author              Barzegaran, M. R.; Zargarzadeh, Hassan; Mohamm...
# Title               Wireless power transfer for electric vehicle u...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 42, Length: 87, dtype: object
# Key                                                          U5YG29BB
# Item Type                                             conferencePaper
# Publication Year                                                 2005
# Author              Lespérance, Éric; Desbiens, Alexis Lussier; Ro...
# Title               Design of a small and low-cost power managemen...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 43, Length: 87, dtype: object
# Key                                                          TKTJUKE4
# Item Type                                              journalArticle
# Publication Year                                                 2011
# Author              Vanderborght, Bram; Tsagarakis, Nikos G.; Van ...
# Title               MACCEPA 2.0: compliant actuator used for energ...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 44, Length: 87, dtype: object
# Key                                                          FQ9CBR4L
# Item Type                                             conferencePaper
# Publication Year                                                 2009
# Author                Umemura, Atushi; Saito, Yukio; Fujisaki, Koichi
# Title               A study on power-assisted rehabilitation robot...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 45, Length: 87, dtype: object
# Key                                                          I8G63286
# Item Type                                             conferencePaper
# Publication Year                                                 2006
# Author              Tsukahara, Kiyoshi; Tanaka, Yorihiko; Sawa, Ka...
# Title               Computer graphics simulator for a power distri...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 46, Length: 87, dtype: object
# Key                                                          XDQ4ZNRL
# Item Type                                              journalArticle
# Publication Year                                                 2008
# Author                                     Zhou, W. U.; Yan-jun, FANG
# Title               Research and Design of Electromagnetic Navigat...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 47, Length: 87, dtype: object
# Key                                                          PD89VI86
# Item Type                                             conferencePaper
# Publication Year                                                 1998
# Author              Hardt, Michael; Kreutz-Delgado, Kenneth; Helto...
# Title               Minimal energy control of a biped robot with n...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 48, Length: 87, dtype: object
# Key                                                          GJP7S7UK
# Item Type                                              journalArticle
# Publication Year                                                 2015
# Author                                Begum, N. Firthous; Vignesh, P.
# Title               Autonomous android controlled robot design usi...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 49, Length: 87, dtype: object
# Key                                                          6ZMYNVKP
# Item Type                                             conferencePaper
# Publication Year                                                 2015
# Author              Shidujaman, Mohammad; Rodriguez, Lenis Tejada;...
# Title               Design and navigation prospective for wireless...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 50, Length: 87, dtype: object
# Key                                                          4W2S6K5K
# Item Type                                             conferencePaper
# Publication Year                                                 2003
# Author              Ishikawa, Masato; Neki, Atsushi; Imura, Jun-ic...
# Title               Energy preserving control of a hopping robot b...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 53, Length: 87, dtype: object
# Key                                                          DL9FRMXA
# Item Type                                              journalArticle
# Publication Year                                                 2010
# Author              Provancher, William R.; Jensen-Segal, Samuel I...
# Title               ROCR: An energy-efficient dynamic wall-climbin...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 54, Length: 87, dtype: object
# Key                                                          7SAWQ98K
# Item Type                                              journalArticle
# Publication Year                                                 2007
# Author                  Wang, Ching-Kuo; Huang, Han-Pang; Chen, Sheng
# Title               The pc-based graphic-user interface of the pow...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 55, Length: 87, dtype: object
# Key                                                          THH79M86
# Item Type                                              journalArticle
# Publication Year                                                 2010
# Author              Sipahioglu, Aydin; Kirlik, Gokhan; Parlaktuna,...
# Title               Energy constrained multi-robot sensor-based co...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 57, Length: 87, dtype: object
# Key                                                          U3U4RQK5
# Item Type                                             conferencePaper
# Publication Year                                                 2006
# Author              Zhou, Fengyu; Xiao, Hairong; Li, Yibin; Wu, Aiguo
# Title               Control strategy and implementation of an insp...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 58, Length: 87, dtype: object
# Key                                                          CY3HIIIJ
# Item Type                                              journalArticle
# Publication Year                                                 2012
# Author              Park, Joon-Young; Lee, Jae-Kyung; Cho, Byung-H...
# Title               An inspection robot for live-line suspension i...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 59, Length: 87, dtype: object
# Key                                                          KZ5752KN
# Item Type                                              journalArticle
# Publication Year                                                 2018
# Author              Goldberg, Benjamin; Zufferey, Raphael; Doshi, ...
# Title               Power and control autonomy for high-speed loco...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 60, Length: 87, dtype: object
# Key                                                          G4IQCGNL
# Item Type                                              journalArticle
# Publication Year                                                 2015
# Author              Kumar, Anup; Samavedi, Srinivas; Bates, Anthon...
# Title               Use of intra-operative indocyanine green and F...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 61, Length: 87, dtype: object
# Key                                                          273NXVZF
# Item Type                                             conferencePaper
# Publication Year                                                 2012
# Author              Roa, Maximo A.; Argus, Max J.; Leidner, Daniel...
# Title               Power grasp planning for anthropomorphic robot...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 62, Length: 87, dtype: object
# Key                                                          ZUWDQAWC
# Item Type                                              journalArticle
# Publication Year                                                 2017
# Author              Mohammed, Abdullah; Schmidt, Bernard; Wang, Lihui
# Title               Energy-efficient robot configuration for assembly
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 63, Length: 87, dtype: object
# Key                                                          39QGS6BH
# Item Type                                              journalArticle
# Publication Year                                                 2014
# Author              Seok, Sangok; Wang, Albert; Chuah, Meng Yee Mi...
# Title               Design principles for energy-efficient legged ...
#                                           ...
# Section                                                           NaN
# ...
# Item Type                                             conferencePaper
# Publication Year                                                 2019
# Author              Tallamraju, Rahul; Verma, Pulkit; Sripada, Ven...
# Title               Energy Conscious Over-actuated Multi-Agent Pay...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 657, Length: 87, dtype: object
# Key                                                          7IQ2VUIK
# Item Type                                              journalArticle
# Publication Year                                                 2015
# Author              Costa, Carlos M.; Sobreira, Héber M.; Sousa, A...
# Title               3 DoF/6 DoF Localization System for Low Comput...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 658, Length: 87, dtype: object
# Key                                                          WYESWGHE
# Item Type                                              journalArticle
# Publication Year                                                 2018
# Author              Kim, Dong-Seok; Lee, Hwang-Jae; Lee, Su-Hyun; ...
# Title               A wearable hip-assist robot reduces the cardio...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 659, Length: 87, dtype: object
# Key                                                          IWY5J4CK
# Item Type                                              journalArticle
# Publication Year                                                  NaN
# Author                                     Amory, Ammar; Maehle, Erik
# Title               SEMBIO: An Energy Efficient Underwater Swarm R...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 660, Length: 87, dtype: object
# Key                                                          UXIY49UA
# Item Type                                             conferencePaper
# Publication Year                                                 2019
# Author                                  Liu, Tao; Li, Hao; Liu, Yiqun
# Title               Computer Simulation and Its Application of a L...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 661, Length: 87, dtype: object
# Key                                                          NFL6Z7EL
# Item Type                                             conferencePaper
# Publication Year                                                 2010
# Author                                          Wang, Liang; Sun, Wei
# Title               Design of Transmission Line Deicing Robot Hybr...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 665, Length: 87, dtype: object
# Key                                                          AB78UKB2
# Item Type                                              journalArticle
# Publication Year                                                 2010
# Author                                                            蘇國嵐
# Title               Develop a Power Detection and Diagnosis Modula...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 666, Length: 87, dtype: object
# Key                                                          VPVKGB8K
# Item Type                                              journalArticle
# Publication Year                                                  NaN
# Author              Ball, David; Wyeth, Gordon; Cusack, David; Rat...
# Title               UQ RoboRoos 2002: Achieving Agility and Power ...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 667, Length: 87, dtype: object
# Key                                                          9TZFJRD3
# Item Type                                                 bookSection
# Publication Year                                                 2012
# Author                                 Nji, Klaus; Mehrandezh, Mehran
# Title               Energy Conservative Design and Nonlinear Contr...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 668, Length: 87, dtype: object
# Key                                                          G5FB2VP5
# Item Type                                              journalArticle
# Publication Year                                                 2019
# Author              Akhlaghi, Vahid Eghbal; Gültekin, Hakan; Gürel...
# Title               Energy conscious scheduling of a material hand...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 670, Length: 87, dtype: object
# Key                                                          CPNVC6WK
# Item Type                                              journalArticle
# Publication Year                                                 2009
# Author                     SMETANOVÁ, PRÁCE Ing ANNA; KOLÍBAL, ZDENĚK
# Title               OPTIMALIZACE ENERGIE PŘI POHYBU ROBOTU OPTIMIZ...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 672, Length: 87, dtype: object
# Key                                                          R2WTFAF5
# Item Type                                              journalArticle
# Publication Year                                                 2013
# Author                                                     Paes, Koen
# Title               On-site identification and energy-optimal path...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 673, Length: 87, dtype: object
# Key                                                          TT8QQCEG
# Item Type                                              journalArticle
# Publication Year                                                 2012
# Author                                              Ventura, Cristina
# Title               Theoretical and Experimental Development of a ...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 674, Length: 87, dtype: object
# Key                                                          RXG283TD
# Item Type                                              journalArticle
# Publication Year                                                 2018
# Author                                               CASATI, FABRIZIO
# Title               ROS-based implementation and evaluation of an ...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 676, Length: 87, dtype: object
# Key                                                          LCJWY6DP
# Item Type                                              journalArticle
# Publication Year                                                 2016
# Author              Wardoyo, Siswo; Saepul, Jajang; Pramudyo, Angg...
# Title               Rancang Bangun Alat Uji Karakteristik Motor DC...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 677, Length: 87, dtype: object
# Key                                                          XF5HJDYH
# Item Type                                              journalArticle
# Publication Year                                                 2018
# Author              Abadi, Vida Shams Esfand; Rostami, Mostafa; Ra...
# Title               Walking Path Prevision of Biped Robot along wi...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 678, Length: 87, dtype: object
# Key                                                       8CEZTE8L
# Item Type                                           journalArticle
# Publication Year                                              2019
# Author                         Almécija Murciano, Francisco Javier
# Title               Power management strategies for a mobile robot
#                                          ...
# Section                                                        NaN
# Session                                                        NaN
# Committee                                                      NaN
# History                                                        NaN
# Legislative Body                                               NaN
# Name: 679, Length: 87, dtype: object
# Key                                                   GXWNQ2F3
# Item Type                                       journalArticle
# Publication Year                                          2001
# Author                                        Krstulović, Ante
# Title               Robot Energy Efficiency Through Redundancy
#                                        ...
# Section                                                    NaN
# Session                                                    NaN
# Committee                                                  NaN
# History                                                    NaN
# Legislative Body                                           NaN
# Name: 680, Length: 87, dtype: object
# Key                                                          YUR8N5QG
# Item Type                                              journalArticle
# Publication Year                                                 2011
# Author                                                            王文俊
# Title               高效率電源管理之智慧型僕役機器人-總計畫: 高效率電源管理之智慧型僕役機器人; Intell...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 681, Length: 87, dtype: object
# Key                                                          DEN4F9BF
# Item Type                                              journalArticle
# Publication Year                                                 2011
# Author              Peña Cortés, César Augusto; Martínez Oviedo, E...
# Title               Dimentional optimization of a Delta parallel r...
#                                           ...
# Section                                                           NaN
# Session                                                           NaN
# Committee                                                         NaN
# History                                                           NaN
# Legislative Body                                                  NaN
# Name: 682, Length: 87, dtype: object
