# %%
import pandas as pd
collection = pd.read_csv('google_scholar_683.csv')
collection
# Out:
#           Key        Item Type  Publication Year  \
# 0    6BH5WM7V   journalArticle            2017.0
# 1    CAV3PKJB   journalArticle            2007.0
# 2    LCA5ZRZQ  conferencePaper            2010.0
# 3    8YQZGJKS   journalArticle            2005.0
# 4    GK66MU6T  conferencePaper            2006.0
# ..        ...              ...               ...
# 678  XF5HJDYH   journalArticle            2018.0
# 679  8CEZTE8L   journalArticle            2019.0
# 680  GXWNQ2F3   journalArticle            2001.0
# 681  YUR8N5QG   journalArticle            2011.0
# 682  DEN4F9BF   journalArticle            2011.0
#
#                                                 Author  \
# 0    Du, Zhihui; He, Ligang; Chen, Yinong; Xiao, Yu...
# 1    Han, Jun; Asada, Akira; Ura, Tamaki; Yamauchi,...
# 2    Wang, Binhai; Chen, Xiguang; Wang, Qian; Liu, ...
# 3                        CAI, Gai-pin; HUANG, Zhi-qing
# 4    Mei, Yongguo; Lu, Yung-Hsiang; Lee, CS George;...
# ..                                                 ...
# 678  Abadi, Vida Shams Esfand; Rostami, Mostafa; Ra...
# 679                Almécija Murciano, Francisco Javier
# 680                                   Krstulović, Ante
# 681                                                王文俊
# 682  Peña Cortés, César Augusto; Martínez Oviedo, E...
#
#                                                  Title  \
# 0    Robot Cloud: Bridging the power of robotics an...
# 1    Noncontact power supply for seafloor geodetic ...
# 2            Power line inspection with a flying robot
# 3    The Realization of the Industrial Revolving Tu...
# 4            Energy-efficient mobile robot exploration
# ..                                                 ...
# 678  Walking Path Prevision of Biped Robot along wi...
# 679     Power management strategies for a mobile robot
# 680         Robot Energy Efficiency Through Redundancy
# 681  高效率電源管理之智慧型僕役機器人-總計畫: 高效率電源管理之智慧型僕役機器人; Intell...
# 682  Dimentional optimization of a Delta parallel r...
#
#                                      Publication Title  ISBN  ISSN  DOI  Url  \
# 0                   Future Generation Computer Systems   NaN   NaN  NaN  NaN
# 1             Journal of marine science and technology   NaN   NaN  NaN  NaN
# 2    2010 1st International Conference on Applied R...   NaN   NaN  NaN  NaN
# 3                            Machine Tool & Hydraulics   NaN   NaN  NaN  NaN
# 4    Proceedings 2006 IEEE International Conference...   NaN   NaN  NaN  NaN
# ..                                                 ...   ...   ...  ...  ...
# 678                     Modares Mechanical Engineering   NaN   NaN  NaN  NaN
# 679                                                NaN   NaN   NaN  NaN  NaN
# 680                                        Strojarstvo   NaN   NaN  NaN  NaN
# 681                             財團法人國家實驗研究院科技政策研究與資訊中心   NaN   NaN  NaN  NaN
# 682                  Ciencia e Ingeniería Neogranadina   NaN   NaN  NaN  NaN
#
#      ...  Programming Language Version System Code  Code Number Section  \
# 0    ...                   NaN     NaN    NaN  NaN          NaN     NaN
# 1    ...                   NaN     NaN    NaN  NaN          NaN     NaN
# 2    ...                   NaN     NaN    NaN  NaN          NaN     NaN
# 3    ...                   NaN     NaN    NaN  NaN          NaN     NaN
# 4    ...                   NaN     NaN    NaN  NaN          NaN     NaN
# ..   ...                   ...     ...    ...  ...          ...     ...
# 678  ...                   NaN     NaN    NaN  NaN          NaN     NaN
# 679  ...                   NaN     NaN    NaN  NaN          NaN     NaN
# 680  ...                   NaN     NaN    NaN  NaN          NaN     NaN
# 681  ...                   NaN     NaN    NaN  NaN          NaN     NaN
# 682  ...                   NaN     NaN    NaN  NaN          NaN     NaN
#
#      Session Committee  History  Legislative Body
# 0        NaN       NaN      NaN               NaN
# 1        NaN       NaN      NaN               NaN
# 2        NaN       NaN      NaN               NaN
# 3        NaN       NaN      NaN               NaN
# 4        NaN       NaN      NaN               NaN
# ..       ...       ...      ...               ...
# 678      NaN       NaN      NaN               NaN
# 679      NaN       NaN      NaN               NaN
# 680      NaN       NaN      NaN               NaN
# 681      NaN       NaN      NaN               NaN
# 682      NaN       NaN      NaN               NaN
#
# [683 rows x 87 columns]

# %%
def filter_types(col):
    df = pd.DataFrame(columns=col.columns)
    for index, row in col.iterrows():
        item_type = row['Item Type']
        df['Item Type'].unique()
        if "journalArticle" in item_type or \
            "conferencePaper" in item_type or \
            "bookSection" in item_type or \
            "book" in item_type:
            df.loc[len(df)] = row
    
    return df

def filter_titles(col):
    df = pd.DataFrame(columns=col.columns)
    for index, row in col.iterrows():
        title = row['Title']
        if "efficiency" in title or \
            "consumption" in title or \
            "optimisation" in title or \
            "optimization" in title or \
            "modeling" in title or \
            "analysis" in title:
            df.loc[len(df)] = row

    return df

# %%
filter_types(filter_titles(collection)).to_csv("filtered_types_and_titles.csv")
